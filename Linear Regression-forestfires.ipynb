# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import  train_test_split

# %%
ffire=pd.read_csv('C:\\Users\\Janu&Vaibh\\Desktop\\HDSfoundation\\forestfires.csv')

# %%
forestfires=pd.DataFrame(ffire)

# %%
forestfires
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# ...

# %%
features=pd.DataFrame(forestfires,columns=['FFMC','DMC','DC','ISI','temp','RH','wind','rain'])
features
# Out:
#      FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 0    86.2   26.2   94.3   5.1   8.2  51   6.7   0.0
# 1    90.6   35.4  669.1   6.7  18.0  33   0.9   0.0
# 2    90.6   43.7  686.9   6.7  14.6  33   1.3   0.0
# 3    91.7   33.3   77.5   9.0   8.3  97   4.0   0.2
# 4    89.3   51.3  102.2   9.6  11.4  99   1.8   0.0
# 5    92.3   85.3  488.0  14.7  22.2  29   5.4   0.0
# 6    92.3   88.9  495.6   8.5  24.1  27   3.1   0.0
# 7    91.5  145.4  608.2  10.7   8.0  86   2.2   0.0
# 8    91.0  129.5  692.6   7.0  13.1  63   5.4   0.0
# 9    92.5   88.0  698.6   7.1  22.8  40   4.0   0.0
# 10   92.5   88.0  698.6   7.1  17.8  51   7.2   0.0
# 11   92.8   73.2  713.0  22.6  19.3  38   4.0   0.0
# 12   63.5   70.8  665.3   0.8  17.0  72   6.7   0.0
# 13   90.9  126.5  686.5   7.0  21.3  42   2.2   0.0
# 14   92.9  133.3  699.6   9.2  26.4  21   4.5   0.0
# 15   93.3  141.2  713.9  13.9  22.9  44   5.4   0.0
# 16   91.7   35.8   80.8   7.8  15.1  27   5.4   0.0
# ...

# %%
target=pd.DataFrame(forestfires,columns=["area"])#features and target are in different dataframes
target
# Out:
#       area
# 0     0.00
# 1     0.00
# 2     0.00
# 3     0.00
# 4     0.00
# 5     0.00
# 6     0.00
# 7     0.00
# 8     0.00
# 9     0.00
# 10    0.00
# 11    0.00
# 12    0.00
# 13    0.00
# 14    0.00
# 15    0.00
# 16    0.00
# 17    0.00
# 18    0.00
# 19    0.00
# 20    0.00
# 21    0.00
# 22    0.00
# 23    0.00
# 24    0.00
# 25    0.00
# 26    0.00
# 27    0.00
# 28    0.00
# 29    0.00
# ..     ...
# 487  16.40
# 488  46.70
# 489   0.00
# 490   0.00
# 491   0.00
# 492   0.00
# 493  43.32
# 494   8.59
# 495   0.00
# 496   2.77
# 497  14.68
# 498  40.54
# 499  10.82
# 500   0.00
# 501   0.00
# 502   0.00
# 503   1.95
# 504  49.59
# 505   5.80
# 506   0.00
# 507   0.00
# 508   0.00
# 509   2.17
# 510   0.43
# 511   0.00
# 512   6.44
# 513  54.29
# 514  11.16
# 515   0.00
# 516   0.00
#
# [517 rows x 1 columns]

# %%
df=pd.concat([features,target],axis=1)
df
# Out:
#      FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# 11   92.8   73.2  713.0  22.6  19.3  38   4.0   0.0   0.00
# 12   63.5   70.8  665.3   0.8  17.0  72   6.7   0.0   0.00
# 13   90.9  126.5  686.5   7.0  21.3  42   2.2   0.0   0.00
# 14   92.9  133.3  699.6   9.2  26.4  21   4.5   0.0   0.00
# ...

# %%
correlation=df.corr('pearson')#pearson gives linear correlation-when u increase 1 unit of feature and how does it respond
correlation#below is correlation matrix
# Out:
#           FFMC       DMC        DC       ISI      temp        RH      wind  \
# FFMC  1.000000  0.382619  0.330512  0.531805  0.431532 -0.300995 -0.028485
# DMC   0.382619  1.000000  0.682192  0.305128  0.469594  0.073795 -0.105342
# DC    0.330512  0.682192  1.000000  0.229154  0.496208 -0.039192 -0.203466
# ISI   0.531805  0.305128  0.229154  1.000000  0.394287 -0.132517  0.106826
# temp  0.431532  0.469594  0.496208  0.394287  1.000000 -0.527390 -0.227116
# RH   -0.300995  0.073795 -0.039192 -0.132517 -0.527390  1.000000  0.069410
# wind -0.028485 -0.105342 -0.203466  0.106826 -0.227116  0.069410  1.000000
# rain  0.056702  0.074790  0.035861  0.067668  0.069491  0.099751  0.061119
# area  0.040122  0.072994  0.049383  0.008258  0.097844 -0.075519  0.012317
#
#           rain      area
# FFMC  0.056702  0.040122
# DMC   0.074790  0.072994
# DC    0.035861  0.049383
# ISI   0.067668  0.008258
# temp  0.069491  0.097844
# RH    0.099751 -0.075519
# wind  0.061119  0.012317
# ...

# %%
X=np.array([df['FFMC'],df['DMC'],df['DC'],df['ISI'],df['temp'],df['RH'],df['wind'],df['rain']])
Y=np.array(df['area'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X=np.transpose(X)
Y=Y.reshape(-1,1)
print(X.shape)
print(Y.shape)
# Out:
# (517, 8)
# (517, 1)

# %%
x=scaler.fit_transform(X)
y=scaler.fit_transform(Y)

# %%
#plt.plot(x,y,'r.')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[ 1.93364130e-02],
#        [-2.89410406e-02],
#        [ 1.49072847e-02],
#        [ 1.44020508e-02],
#        [ 1.82318010e-02],
#        [ 2.30734041e-02],
#        [ 3.77733286e-04],
#        [ 8.69839233e-03],
#        [ 1.50899027e-02],
#        [ 1.99519679e-02],
#        [ 9.80343107e-03],
#        [ 7.00452470e-03],
#        [ 1.08065004e-02],
#        [ 1.06958754e-02],
#        [ 1.97514468e-02],
#        [ 8.32562701e-05],
#        [ 1.37096117e-02],
#        [ 1.61739781e-02],
#        [ 2.18175451e-02],
#        [ 2.19016396e-02],
#        [ 2.65710171e-02],
#        [ 2.00720345e-02],
#        [ 5.25980912e-03],
#        [ 3.10434682e-02],
#        [ 1.07615863e-02],
#        [ 5.80568271e-03],
#        [ 1.54856616e-02],
#        [ 6.69520477e-03],
#        [ 2.22919839e-02],
#        [ 2.17863986e-02],
#        [ 1.11689767e-02],
#        [ 5.59467910e-03],
#        [ 1.94102148e-02],
#        [ 7.52006278e-03],
#        [ 3.47428971e-02],
# ...

# %%
for i in zip(y_pred,y_test):
    print(i)
# Out:
# (array([0.01933641]), array([0.09686113]))
# (array([-0.02894104]), array([0.]))
# (array([0.01490728]), array([0.]))
# (array([0.01440205]), array([0.]))
# (array([0.0182318]), array([0.00798467]))
# (array([0.0230734]), array([0.]))
# (array([0.00037773]), array([0.00150343]))
# (array([0.00869839]), array([0.]))
# (array([0.0150899]), array([0.]))
# (array([0.01995197]), array([0.00918558]))
# (array([0.00980343]), array([0.]))
# (array([0.00700452]), array([0.]))
# (array([0.0108065]), array([0.]))
# (array([0.01069588]), array([0.]))
# (array([0.01975145]), array([0.00124675]))
# (array([8.32562701e-05]), array([0.]))
# (array([0.01370961]), array([0.05344505]))
# (array([0.01617398]), array([0.]))
# (array([0.02181755]), array([0.]))
# (array([0.02190164]), array([0.]))
# (array([0.02657102]), array([0.02634667]))
# (array([0.02007203]), array([0.]))
# (array([0.00525981]), array([0.01282498]))
# (array([0.03104347]), array([0.02422903]))
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.00048446562820662523

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),'b')
plt.xlabel("RM")
plt.ylabel("TARGET")
plt.title("Linear Regression(Train)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-b07893aa0d67> in <module>
# ----> 1 plt.scatter(x_train,y_train,color='red')
#       2 plt.plot(x_train,regressor.predict(x_train),'b')
#       3 plt.xlabel("RM")
#       4 plt.ylabel("TARGET")
#       5 plt.title("Linear Regression(Train)")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,regressor.predict(x_test),'b')
plt.xlabel("RM")
plt.ylabel("TARGET")
plt.title("Linear Regression(Train)")
# Out:
# Text(0.5, 1.0, 'Linear Regression(Train)')

# %%
r2_score(y_test,y_pred)#tells the best possible fit:percentage of points to be fitted
# Out:
# -0.2861558403812243
